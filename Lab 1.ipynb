# %%
# PROGRAM 1: Write a program to simulate an Automatic Headlight Control System that turns the
# PROGRAM 1: Automatic Headlight Control System
# Turns headlights ON/OFF based on ambient light intensity.

import cv2
import numpy as np

from tensorflow.keras.applications import MobileNetV2
from tensorflow.keras.applications.mobilenet_v2 import (
    preprocess_input,
    decode_predictions
)

# Load pretrained CNN
model = MobileNetV2(weights="imagenet")

# Read an image (camera sensor simulation)
image = cv2.imread("day.jpg")

# Check if image was loaded
if image is None:
    print("Error: day.jpg not found!")
else:
    # Resize image
    img = cv2.resize(image, (224, 224))

    # Prepare image
    x = np.expand_dims(img, axis=0)
    x = preprocess_input(x)

    # CNN Prediction
    predictions = model.predict(x, verbose=0)

    print("CNN Prediction:")
    print(decode_predictions(predictions, top=3)[0])

    # Calculate ambient brightness
    gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    brightness = np.mean(gray)

    print("Ambient Brightness:", brightness)

    # Automatic headlight control
    threshold = 100

    if brightness < threshold:
        print("Headlights: ON")
    else:
        print("Headlights: OFF")
# Out:
# CNN Prediction:
# [('n09428293', 'seashore', np.float32(0.22795527)), ('n09421951', 'sandbar', np.float32(0.062140863)), ('n09332890', 'lakeside', np.float32(0.05066305))]
# Ambient Brightness: 136.54371027257056
# Headlights: OFF
